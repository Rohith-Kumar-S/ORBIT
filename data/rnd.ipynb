# %%
import numpy as np
import pandas as pd
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/amazon-products-dataset-2023-1-4m-products")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.13)
# Path to dataset files: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\amazon-products-dataset-2023-1-4m-products\versions\17

# %%
os.listdir(path)
# Out:
# ['amazon_categories.csv', 'amazon_products.csv']

# %%
products_path = os.path.join(path, 'amazon_products.csv')
categories_path = os.path.join(path, 'amazon_categories.csv')
products = pd.read_csv(products_path)
categories = pd.read_csv(categories_path)

# %%
categories
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
products.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# 2  https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49     429.99
# 3  https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59     354.37
# 4  https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99     309.99
#
#    category_id  isBestSeller  boughtInLastMonth
# 0          104         False               2000
# 1          104         False               1000
# 2          104         False                300
# 3          104         False                400
# 4          104         False                400

# %%
products['seller_id'] = 1

# %%
products.drop(columns=['productURL','listPrice', 'isBestSeller', 'boughtInLastMonth'], inplace=True)

# %%
products
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  stars  reviews  \
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...    4.5        0
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...    4.5        0
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...    4.6        0
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...    4.6        0
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...    4.5        0
# ...                                                    ...    ...      ...
# 1426332  https://m.media-amazon.com/images/I/71PDJFz6AA...    4.2        0
# 1426333  https://m.media-amazon.com/images/I/812Tycexs4...    4.4        0
# 1426334  https://m.media-amazon.com/images/I/61vvYW1S9J...    3.6        0
# 1426335  https://m.media-amazon.com/images/I/51+yjD4F1x...    4.5        0
# 1426336  https://m.media-amazon.com/images/I/91Kt2KQf0E...    4.9        0
#
#           price  category_id  seller_id
# 0        139.99          104          1
# 1        169.99          104          1
# 2        365.49          104          1
# 3        291.59          104          1
# 4        174.99          104          1
# ...         ...          ...        ...
# 1426332   14.95          112          1
# 1426333   33.99          112          1
# 1426334    8.54          112          1
# 1426335   54.36          112          1
# 1426336   18.79          112          1
#
# [1426337 rows x 8 columns]

# %%
df = products.groupby('category_id').head(1000)

# %%
table_columns = ["id" ,
"title" ,
"img_url" ,
"rating" ,
"review_count" ,
"price" ,
"category_id",
"seller_id"
]

# %%
df.columns = table_columns

# %%
len(df)
# Out:
# 224788

# %%
df
# Out:
#                  id                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1415987  B09VB58HHV  Double Din Car Stereo Touchscreen - 10 Inch Fl...
# 1415988  B083QCQHT2  Key Fob for 2008-2015 Chrysler Town and Countr...
# 1415989  B09538R5VL  Phone Mount for Car [Heavy Duty Super Suction]...
# 1415990  B005V9UU1O  Install Bay Split Loom 1/4 Inch 100 Foot Coil ...
# 1415991  B00845ATKY  Aftermarket Radio Stereo Double Din Dash Insta...
#
#                                                    img_url  rating  \
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...     4.5
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...     4.5
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...     4.6
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...     4.6
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...     4.5
# ...                                                    ...     ...
# 1415987  https://m.media-amazon.com/images/I/71DgI27KJY...     3.9
# 1415988  https://m.media-amazon.com/images/I/51OkqH8Gzw...     4.1
# 1415989  https://m.media-amazon.com/images/I/81YR-DbqHE...     4.3
# 1415990  https://m.media-amazon.com/images/I/81LgoTj2Jk...     4.5
# 1415991  https://m.media-amazon.com/images/I/41Jyi-ZM8V...     4.4
#
#          review_count   price  category_id  seller_id
# 0                   0  139.99          104          1
# 1                   0  169.99          104          1
# 2                   0  365.49          104          1
# 3                   0  291.59          104          1
# 4                   0  174.99          104          1
# ...               ...     ...          ...        ...
# 1415987             0  225.99           26          1
# 1415988             0   13.99           26          1
# 1415989             0    9.99           26          1
# 1415990             0   11.49           26          1
# 1415991             0   28.50           26          1
#
# [224788 rows x 8 columns]

# %%
df.to_csv("minimal_products.csv", index=False)

# %%
# catgories update

# %%
df = pd.read_csv('amazon_categories.csv')

# %%
df
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
df.iloc[9]
# Out:
# id                                             10
# category_name    Painting, Drawing & Art Supplies
# Name: 9, dtype: object
