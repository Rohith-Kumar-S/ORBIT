# %%
import numpy as np
import pandas as pd
import os

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("asaniczka/amazon-products-dataset-2023-1-4m-products")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.13)
# Path to dataset files: C:\Users\rohit\.cache\kagglehub\datasets\asaniczka\amazon-products-dataset-2023-1-4m-products\versions\17

# %%
os.listdir(path)
# Out:
# ['amazon_categories.csv', 'amazon_products.csv']

# %%
products_path = os.path.join(path, 'amazon_products.csv')
categories_path = os.path.join(path, 'amazon_categories.csv')
products = pd.read_csv(products_path)
categories = pd.read_csv(categories_path)

# %%
categories
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
products.head()
# Out:
#                                                title  \
# 0  Sion Softside Expandable Roller Luggage, Black...
# 1  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  Platinum Elite Softside Expandable Checked Lug...
# 3  Freeform Hardside Expandable with Double Spinn...
# 4  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl   price  category_id  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...  139.99          104
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...  169.99          104
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...  365.49          104
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...  291.59          104
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...  174.99          104
#
#    seller_id
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
products['seller_id'] = 1

# %%
products.drop(columns=['productURL','listPrice', 'isBestSeller', 'boughtInLastMonth'], inplace=True)

# %%
products.reset_index( inplace=True)

# %%
products
# Out:
#            index                                              title  \
# 0              0  Sion Softside Expandable Roller Luggage, Black...
# 1              1  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2              2  Platinum Elite Softside Expandable Checked Lug...
# 3              3  Freeform Hardside Expandable with Double Spinn...
# 4              4  Winfield 2 Hardside Expandable Luggage with Sp...
# ...          ...                                                ...
# 1426332  1426332  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  1426333  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  1426334  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  1426335                          Ax2002 Aviator Sunglasses
# 1426336  1426336  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl   price  \
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...  139.99
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...  169.99
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...  365.49
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...  291.59
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...  174.99
# ...                                                    ...     ...
# 1426332  https://m.media-amazon.com/images/I/71PDJFz6AA...   14.95
# 1426333  https://m.media-amazon.com/images/I/812Tycexs4...   33.99
# 1426334  https://m.media-amazon.com/images/I/61vvYW1S9J...    8.54
# 1426335  https://m.media-amazon.com/images/I/51+yjD4F1x...   54.36
# 1426336  https://m.media-amazon.com/images/I/91Kt2KQf0E...   18.79
#
#          category_id  seller_id
# 0                104          1
# 1                104          1
# 2                104          1
# 3                104          1
# 4                104          1
# ...              ...        ...
# 1426332          112          1
# 1426333          112          1
# 1426334          112          1
# 1426335          112          1
# 1426336          112          1
#
# [1426337 rows x 6 columns]

# %%
# df = products.groupby('category_id').head(10)

# %%
table_columns = ["id" ,
"title" ,
"img_url" ,
"rating" ,
"review_count" ,
"price" ,
"category_id",
"seller_id"
]

# %%
products.columns = table_columns

# %%
len(products)
# Out:
# 1426337

# %%
products
# Out:
#               id                                              title  \
# 0              0  Sion Softside Expandable Roller Luggage, Black...
# 1              1  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2              2  Platinum Elite Softside Expandable Checked Lug...
# 3              3  Freeform Hardside Expandable with Double Spinn...
# 4              4  Winfield 2 Hardside Expandable Luggage with Sp...
# ...          ...                                                ...
# 1426332  1426332  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  1426333  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  1426334  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  1426335                          Ax2002 Aviator Sunglasses
# 1426336  1426336  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                    img_url   price  \
# 0        https://m.media-amazon.com/images/I/815dLQKYIY...  139.99
# 1        https://m.media-amazon.com/images/I/81bQlm7vf6...  169.99
# 2        https://m.media-amazon.com/images/I/71EA35zvJB...  365.49
# 3        https://m.media-amazon.com/images/I/91k6NYLQyI...  291.59
# 4        https://m.media-amazon.com/images/I/61NJoaZcP9...  174.99
# ...                                                    ...     ...
# 1426332  https://m.media-amazon.com/images/I/71PDJFz6AA...   14.95
# 1426333  https://m.media-amazon.com/images/I/812Tycexs4...   33.99
# 1426334  https://m.media-amazon.com/images/I/61vvYW1S9J...    8.54
# 1426335  https://m.media-amazon.com/images/I/51+yjD4F1x...   54.36
# 1426336  https://m.media-amazon.com/images/I/91Kt2KQf0E...   18.79
#
#          category_id  seller_id
# 0                104          1
# 1                104          1
# 2                104          1
# 3                104          1
# 4                104          1
# ...              ...        ...
# 1426332          112          1
# 1426333          112          1
# 1426334          112          1
# 1426335          112          1
# 1426336          112          1
#
# [1426337 rows x 6 columns]

# %%
products.to_csv("minimal_products.csv", index=False)
